# %% [markdown]
# ## Prepare Eval Dataset

# %%
import pandas as pd
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/renoldnatasasmita/Datalabs/Project/GenaiSpecialization/sa.json"

PATH = 'final_qa_val.jsonl'
examples = pd.read_json(PATH, lines=True)
# Tambahkan kode untuk mengekstrak question dan answer
def extract_qa(row):
    contents = row['contents']
    question = contents[0]['parts'][0]['text']  # Mengambil pertanyaan dari user
    answer = contents[1]['parts'][0]['text'] if len(contents) > 1 else None  # Mengambil jawaban jika ada
    return pd.Series({'content': question, 'response_a': answer})

# Terapkan ekstraksi dan gabungkan dengan DataFrame asli
qa_df = examples.apply(extract_qa, axis=1)
examples = pd.concat([examples, qa_df], axis=1)

# %%
examples.head()
# Out:
#                                             contents  \
# 0  [{'role': 'user', 'parts': [{'text': 'What is ...
# 1  [{'role': 'user', 'parts': [{'text': "Can you ...
# 2  [{'role': 'user', 'parts': [{'text': 'What doe...
# 3  [{'role': 'user', 'parts': [{'text': 'How does...
# 4  [{'role': 'user', 'parts': [{'text': 'What is ...
#
#                                              content  \
# 0  What is the purpose of hydraulic storage in beds?
# 1        Can you explain the term 'Engineered Wood'?
# 2                  What does GSM in bed linens mean?
# 3      How does a recliner mechanism work in chairs?
# 4  What is the difference between PVC and PU leat...
#
#                                           response_a
# 0  Hydraulic storage in beds uses a lift mechanis...
# 1  'Engineered Wood' refers to a composite materi...
# 2  GSM stands for grams per square meter, indicat...
# 3  A recliner mechanism allows the chair's backre...
# 4  PVC leather is more durable and water-resistan...

# %%
examples = examples.drop(columns=['contents'])
# add id column
examples['id'] = examples.index
# add content column but just string
examples['response_b'] = ""
examples.head()
# Out:
#                                              content  \
# 0  What is the purpose of hydraulic storage in beds?
# 1        Can you explain the term 'Engineered Wood'?
# 2                  What does GSM in bed linens mean?
# 3      How does a recliner mechanism work in chairs?
# 4  What is the difference between PVC and PU leat...
#
#                                           response_a  id response_b
# 0  Hydraulic storage in beds uses a lift mechanis...   0
# 1  'Engineered Wood' refers to a composite materi...   1
# 2  GSM stands for grams per square meter, indicat...   2
# 3  A recliner mechanism allows the chair's backre...   3
# 4  PVC leather is more durable and water-resistan...   4

# %%
# Call Fine Tuned Model
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, SafetySetting, Part

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
}

safety_settings = [
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
        threshold=SafetySetting.HarmBlockThreshold.OFF
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
        threshold=SafetySetting.HarmBlockThreshold.OFF
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
        threshold=SafetySetting.HarmBlockThreshold.OFF
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
        threshold=SafetySetting.HarmBlockThreshold.OFF
    ),
]

def multiturn_generate_content(question):
    vertexai.init(project="844021890758", location="asia-southeast1")
    model = GenerativeModel(
        "projects/844021890758/locations/asia-southeast1/endpoints/5071110355023822848",
    )
    chat = model.start_chat()
    ans = chat.send_message(question, generation_config=generation_config, safety_settings=safety_settings)
    return ans.candidates[0].content.parts[0].text

# Apply the function to the 'question' column
examples['response_b'] = examples['content'].apply(multiturn_generate_content)
examples.head()
# Out:
#                                              content  \
# 0  What is the purpose of hydraulic storage in beds?
# 1        Can you explain the term 'Engineered Wood'?
# 2                  What does GSM in bed linens mean?
# 3      How does a recliner mechanism work in chairs?
# 4  What is the difference between PVC and PU leat...
#
#                                           response_a  id  \
# 0  Hydraulic storage in beds uses a lift mechanis...   0
# 1  'Engineered Wood' refers to a composite materi...   1
# 2  GSM stands for grams per square meter, indicat...   2
# 3  A recliner mechanism allows the chair's backre...   3
# 4  PVC leather is more durable and water-resistan...   4
#
#                                           response_b
# 0  There's no established concept of "hydraulic s...
# 1  Engineered wood, also known as composite wood,...
# 2  GSM in bed linens stands for **Grams per Squar...
# 3  A recliner mechanism allows a chair to smoothl...
# 4  PVC and PU leather are both synthetic material...

# %%
# Eval dataset from examples but change the column names into prompt, response, baseline_model_response
eval_dataset = examples.rename(columns={"content": "prompt", "response_a": "reference", "response_b": "response"})
eval_dataset.head()
# Out:
#                                               prompt  \
# 0  What is the purpose of hydraulic storage in beds?
# 1        Can you explain the term 'Engineered Wood'?
# 2                  What does GSM in bed linens mean?
# 3      How does a recliner mechanism work in chairs?
# 4  What is the difference between PVC and PU leat...
#
#                                            reference  id  \
# 0  Hydraulic storage in beds uses a lift mechanis...   0
# 1  'Engineered Wood' refers to a composite materi...   1
# 2  GSM stands for grams per square meter, indicat...   2
# 3  A recliner mechanism allows the chair's backre...   3
# 4  PVC leather is more durable and water-resistan...   4
#
#                                             response
# 0  There's no established concept of "hydraulic s...
# 1  Engineered wood, also known as composite wood,...
# 2  GSM in bed linens stands for **Grams per Squar...
# 3  A recliner mechanism allows a chair to smoothl...
# 4  PVC and PU leather are both synthetic material...

# %%
eval_dataset.to_json("eval_dataset.json", orient="records", lines=True)

# %% [markdown]
# ## Start EVAL

# %%
import pandas as pd
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/renoldnatasasmita/Datalabs/Project/GenaiSpecialization/sa.json"
eval_dataset = pd.read_json("eval_dataset.json", lines=True)
eval_dataset.head()
# Out:
#                                               prompt  \
# 0  What is the purpose of hydraulic storage in beds?
# 1        Can you explain the term 'Engineered Wood'?
# 2                  What does GSM in bed linens mean?
# 3      How does a recliner mechanism work in chairs?
# 4  What is the difference between PVC and PU leat...
#
#                                            reference  id  \
# 0  Hydraulic storage in beds uses a lift mechanis...   0
# 1  'Engineered Wood' refers to a composite materi...   1
# 2  GSM stands for grams per square meter, indicat...   2
# 3  A recliner mechanism allows the chair's backre...   3
# 4  PVC leather is more durable and water-resistan...   4
#
#                                             response
# 0  There's no established concept of "hydraulic s...
# 1  Engineered wood, also known as composite wood,...
# 2  GSM in bed linens stands for **Grams per Squar...
# 3  A recliner mechanism allows a chair to smoothl...
# 4  PVC and PU leather are both synthetic material...

# %%
from vertexai.evaluation import (
    EvalTask,
    PairwiseMetric,
    PairwiseMetricPromptTemplate,
    PointwiseMetric,
    PointwiseMetricPromptTemplate,
    MetricPromptTemplateExamples
)

# %%
metrics = [
    "bleu",
    "rouge_l_sum",
    MetricPromptTemplateExamples.Pointwise.FLUENCY,
    MetricPromptTemplateExamples.Pointwise.COHERENCE,
]

# %%
eval_task = EvalTask(
    dataset=eval_dataset,
    metrics=metrics,
    experiment="demo3-pairwise-experiment-eval-fine-tuned-model"
)

# %%
import vertexai
vertexai.init(project="dla-gen-ai-specialization", location="asia-southeast1")

# %%
eval_result = eval_task.evaluate(
    experiment_run_name="demo3-pairwise-experiment-eval-fine-tuned-model"
)
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-6b9a9158-406d-420e-929d-858a3fee467e" href="#view-view-vertex-resource-6b9a9158-406d-420e-929d-858a3fee467e">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-6b9a9158-406d-420e-929d-858a3fee467e');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/asia-southeast1/experiments/demo3-pairwise-experiment-eval-fine-tuned-model/runs?project=dla-gen-ai-specialization');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/asia-southeast1/experiments/demo3-pairwise-experiment-eval-fine-tuned-model/runs?project=dla-gen-ai-specialization', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# Associating projects/844021890758/locations/asia-southeast1/metadataStores/default/contexts/demo3-pairwise-experiment-eval-fine-tuned-model-demo3-pairwise-experiment-eval-fine-tuned-model to Experiment: demo3-pairwise-experiment-eval-fine-tuned-model
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-782d2229-397d-4e88-abc4-3256dd06ca99" href="#view-view-vertex-resource-782d2229-397d-4e88-abc4-3256dd06ca99">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-782d2229-397d-4e88-abc4-3256dd06ca99');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/asia-southeast1/experiments/demo3-pairwise-experiment-eval-fine-tuned-model/runs/demo3-pairwise-experiment-eval-fine-tuned-model-demo3-pairwise-experiment-eval-fine-tuned-model?project=dla-gen-ai-specialization');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/asia-southeast1/experiments/demo3-pairwise-experiment-eval-fine-tuned-model/runs/demo3-pairwise-experiment-eval-fine-tuned-model-demo3-pairwise-experiment-eval-fine-tuned-model?project=dla-gen-ai-specialization', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# Computing metrics with a total of 200 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 200/200 [13:22<00:00,  4.01s/it]
# All 200 metric requests are successfully computed.
# Evaluation Took:802.615517875005 seconds

# %%
eval_result.metrics_table
# Out:
#                                                prompt  \
# 0   What is the purpose of hydraulic storage in beds?
# 1         Can you explain the term 'Engineered Wood'?
# 2                   What does GSM in bed linens mean?
# 3       How does a recliner mechanism work in chairs?
# 4   What is the difference between PVC and PU leat...
# 5   What is the advantage of tempered glass in fur...
# 6   How does particle board differ from MDF in cab...
# 7   What does the term 'Pocket Spring Mattress' re...
# 8              What is the use of coir in mattresses?
# 9   How do you maintain wooden furniture for long-...
# 10  What does a 1-year warranty typically cover in...
# 11          What is meant by a modular kitchen setup?
# 12  How do I identify solid wood furniture from al...
# 13    What are the features of orthopedic mattresses?
# 14            What does pre-assembled furniture mean?
# 15  What is the purpose of a veneer finish in furn...
# 16  How does foam density affect the comfort of a ...
# 17    What does the term 'Wall-Mounted Unit' signify?
# 18  What is the role of castor wheels in office ch...
# 19  How do adjustable armrests enhance chair ergon...
# 20    What does the term 'Convertible Sofa Bed' mean?
# 21  What are the pros and cons of high-gloss furni...
# 22  How does water-resistance work in outdoor furn...
# 23  What does a laminate surface provide in desks ...
# 24         What is the meaning of FSC-certified wood?
# 25         What is the use of a tufted back in sofas?
# 26           What does anti-skid design mean in rugs?
# 27  What are the benefits of spring cushioning in ...
# 28  What is the difference between a coffee table ...
# 29        How does a sliding door mechanism function?
# 30  What is the importance of UV resistance in out...
# 31  What does a push-back mechanism mean in reclin...
# 32  What is the role of ball-bearing slides in dra...
# 33  How does a mid-century modern design differ fr...
# 34  What is the benefit of soft-close hinges in ca...
# 35                How does a drop-leaf table operate?
# 36                    What does kiln-dried wood mean?
# 37  What are the benefits of a polyester finish in...
# 38           How does stackable furniture save space?
# 39       What is the purpose of a box spring in beds?
# 40  What does scratch-resistant coating do for tab...
# 41              What is a swivel mechanism in chairs?
# 42  What is the difference between natural and syn...
# 43  What is the advantage of having a storage otto...
# 44  How does an L-shaped sofa differ from a sectio...
# 45  What is the role of resin wicker in outdoor fu...
# 46                  How does a Murphy bed save space?
# 47  What is the significance of a dovetail joint i...
# 48    What does anti-tip design mean for bookshelves?
# 49  What are the advantages of aluminum frames in ...
#
#                                             reference  id  \
# 0   Hydraulic storage in beds uses a lift mechanis...   0
# 1   'Engineered Wood' refers to a composite materi...   1
# 2   GSM stands for grams per square meter, indicat...   2
# 3   A recliner mechanism allows the chair's backre...   3
# 4   PVC leather is more durable and water-resistan...   4
# 5   Tempered glass is stronger and safer than regu...   5
# 6   Particle board is lighter and less expensive, ...   6
# 7   A pocket spring mattress contains individually...   7
# 8   Coir, made from coconut fibers, is used in mat...   8
# 9   To maintain wooden furniture, avoid direct sun...   9
# 10  A 1-year warranty typically covers manufacturi...  10
# 11  A modular kitchen setup consists of pre-design...  11
# 12  Solid wood furniture typically has natural gra...  12
# 13  Orthopedic mattresses provide firm support, al...  13
# 14  Pre-assembled furniture is delivered fully bui...  14
# 15  A veneer finish adds an elegant wood layer to ...  15
# 16  Foam density determines the sofa's firmness an...  16
# 17  A 'Wall-Mounted Unit' is furniture affixed to ...  17
# 18  Castor wheels enable smooth movement of office...  18
# 19  Adjustable armrests allow users to customize a...  19
# 20  A 'Convertible Sofa Bed' functions as both a s...  20
# 21  High-gloss furniture finishes are stylish and ...  21
# 22  Water-resistant outdoor furniture is coated to...  22
# 23  A laminate surface protects desks and tables, ...  23
# 24  FSC-certified wood is sustainably sourced, ens...  24
# 25  A tufted back in sofas provides enhanced aesth...  25
# 26  Anti-skid design in rugs prevents slipping by ...  26
# 27  Spring cushioning offers enhanced support, com...  27
# 28  A coffee table is placed centrally in a living...  28
# 29  A sliding door mechanism operates on a track s...  29
# 30  UV resistance prevents outdoor furniture from ...  30
# 31  A push-back mechanism allows the backrest to r...  31
# 32  Ball-bearing slides enable drawers to open and...  32
# 33  Mid-century modern design features clean lines...  33
# 34  Soft-close hinges prevent cabinets from slammi...  34
# 35  A drop-leaf table has hinged sections that can...  35
# 36  Kiln-dried wood is dried in a controlled envir...  36
# 37  A polyester finish is durable, stain-resistant...  37
# 38  Stackable furniture is designed to be nested o...  38
# 39  A box spring provides foundational support for...  39
# 40  Scratch-resistant coating protects tables from...  40
# 41  A swivel mechanism allows chairs to rotate 360...  41
# 42  Natural fibers are eco-friendly and breathable...  42
# 43  A storage ottoman combines seating or footrest...  43
# 44  An L-shaped sofa is a single unit, while a sec...  44
# 45  Resin wicker is weather-resistant and durable,...  45
# 46  A Murphy bed folds into a wall or cabinet, fre...  46
# 47  Dovetail joints are strong and durable, enhanc...  47
# 48  Anti-tip design includes features to prevent b...  48
# 49  Aluminum frames are lightweight, rust-resistan...  49
#
#                                              response  bleu/score  \
# 0   There's no established concept of "hydraulic s...    0.006745
# 1   Engineered wood, also known as composite wood,...    0.010385
# 2   GSM in bed linens stands for **Grams per Squar...    0.060371
# 3   A recliner mechanism allows a chair to smoothl...    0.010860
# 4   PVC and PU leather are both synthetic material...    0.012718
# 5   Tempered glass offers several advantages when ...    0.022773
# 6   Particle board and MDF (medium-density fiberbo...    0.003327
# 7   A pocket spring mattress refers to a mattress ...    0.130406
# 8   Coir, a natural fiber extracted from the husk ...    0.023049
# 9   Maintaining wooden furniture for long-term dur...    0.004289
# 10  A 1-year warranty on furniture typically cover...    0.012863
# 11  A modular kitchen setup is a kitchen designed ...    0.013690
# 12  Identifying solid wood furniture from alternat...    0.004182
# 13  Orthopedic mattresses are designed to provide ...    0.004888
# 14  Pre-assembled furniture means that the furnitu...    0.048412
# 15  The purpose of a veneer finish in furniture is...    0.007420
# 16  Foam density significantly impacts sofa comfor...    0.004805
# 17  "Wall-mounted unit" signifies a piece of equip...    0.012331
# 18  Castor wheels, also known as office chair whee...    0.016580
# 19  Adjustable armrests significantly enhance chai...    0.013762
# 20  A convertible sofa bed is a piece of furniture...    0.111595
# 21  High-gloss furniture finishes offer a sleek, m...    0.011064
# 22  Water resistance in outdoor furniture isn't ab...    0.005478
# 23  Laminate surfaces on desks and tables offer se...    0.012219
# 24  FSC-certified wood comes from forests that are...    0.012227
# 25  A tufted back on a sofa serves several purpose...    0.008943
# 26  Anti-skid design in rugs refers to features in...    0.022675
# 27  Spring cushioning in sofas offers several bene...    0.003885
# 28  The main difference between a coffee table and...    0.065126
# 29  A sliding door mechanism's function relies on ...    0.013178
# 30  UV resistance in outdoor furniture is incredib...    0.004675
# 31  In a recliner with a push-back mechanism, you ...    0.033821
# 32  Ball-bearing slides in drawers provide **smoot...    0.026128
# 33  While both mid-century modern and contemporary...    0.009405
# 34  The main benefit of soft-close hinges is that ...    0.014583
# 35  A drop-leaf table uses hinged leaves that can ...    0.017574
# 36  Kiln-dried wood is wood that has been dried in...    0.037065
# 37  Polyester upholstery fabrics offer several ben...    0.013062
# 38  Stackable furniture saves space primarily by a...    0.027822
# 39  The primary purpose of a box spring is to **pr...    0.004735
# 40  A scratch-resistant coating on a table protect...    0.016997
# 41  A swivel mechanism in a chair allows the seat ...    0.009439
# 42  The main difference between natural and synthe...    0.005324
# 43  Storage ottomans offer several advantages:\n\n...    0.004890
# 44  While both L-shaped sofas and sectionals offer...    0.040114
# 45  Resin wicker, also known as synthetic wicker, ...    0.010436
# 46  A Murphy bed, also known as a wall bed or fold...    0.091274
# 47  The dovetail joint's significance in drawers l...    0.004743
# 48  An anti-tip design for a bookshelf refers to f...    0.020047
# 49  Aluminum frames offer several advantages for p...    0.005382
#
#     rouge_l_sum/score                                fluency/explanation  \
# 0            0.138365  STEP 1: Assess grammar correctness: The respon...
# 1            0.078029  STEP 1: Assess grammar correctness: The respon...
# 2            0.500000  STEP 1: Assess grammar correctness: The respon...
# 3            0.056795  STEP 1: Assess grammar correctness: The respon...
# 4            0.099217  STEP 1: Assess grammar correctness: The respon...
# 5            0.129870  STEP 1: Assess grammar correctness: The respon...
# 6            0.067416  STEP 1: Assess grammar correctness: The respon...
# 7            0.315789  STEP 1: Assess grammar correctness: The respon...
# 8            0.118919  STEP 1: Assess grammar correctness: The respon...
# 9            0.066390  STEP 1: Assess grammar correctness: The respon...
# 10           0.067797  STEP 1: Assess grammar correctness: The respon...
# 11           0.109705  STEP 1: Assess grammar correctness: The respon...
# 12           0.041353  STEP 1: Assess grammar correctness: The respon...
# 13           0.060150  STEP 1: Assess grammar correctness: The respon...
# 14           0.193548  STEP 1: Assess grammar correctness: The respon...
# 15           0.083682  STEP 1: Assess grammar correctness: The respon...
# 16           0.084507  STEP 1: Assess grammar correctness: The respon...
# 17           0.144928  STEP 1: Assess grammar correctness: The respon...
# 18           0.151261  STEP 1: Assess grammar correctness: The respon...
# 19           0.055385  STEP 1: Assess grammar correctness: The respon...
# 20           0.320000  STEP 1: Assess grammar correctness: The respon...
# 21           0.056657  STEP 1: Assess grammar correctness: The respon...
# 22           0.074499  STEP 1: Assess grammar correctness: The respon...
# 23           0.086957  STEP 1: Assess grammar correctness: The respon...
# 24           0.088670  STEP 1: Assess grammar correctness:\nThe respo...
# 25           0.083721  STEP 1: Assess grammar correctness: The respon...
# 26           0.104762  STEP 1: Assess grammar correctness: The respon...
# 27           0.049296  STEP 1: Assess grammar correctness: The respon...
# 28           0.222222  STEP 1: Assess grammar correctness: The respon...
# 29           0.071429  STEP 1: Assess grammar correctness: The respon...
# 30           0.056452  STEP 1: The response exhibits excellent gramma...
# 31           0.192308  STEP 1: Assess grammar correctness: The respon...
# 32           0.118421  STEP 1: Assess grammar correctness: The respon...
# 33           0.075472  STEP 1: Assess grammar correctness: The respon...
# 34           0.125000  STEP 1: Assess grammar correctness: The respon...
# 35           0.097015  STEP 1: Assess grammar correctness: The respon...
# 36           0.193548  STEP 1: Assess grammar correctness:\nThe respo...
# 37           0.100840  STEP 1: Assess grammar correctness: The respon...
# 38           0.116279  STEP 1: Assess grammar correctness: The respon...
# 39           0.074468  STEP 1: Assess grammar correctness: The respon...
# 40           0.098361  STEP 1: Assess grammar correctness: The respon...
# 41           0.079545  STEP 1: Assess grammar correctness: The respon...
# 42           0.081633  STEP 1: Assess grammar correctness: The respon...
# 43           0.072727  STEP 1: Assess grammar correctness: The respon...
# 44           0.193548  STEP 1: Assess grammar correctness: The respon...
# 45           0.099237  STEP 1: Assess grammar correctness: The respon...
# 46           0.309524  STEP 1: Assess grammar correctness: The respon...
# 47           0.108374  STEP 1: Assess grammar correctness: The respon...
# 48           0.117021  STEP 1: Assess grammar correctness: The respon...
# 49           0.070352  STEP 1: Assess grammar correctness: The respon...
#
#     fluency/score                              coherence/explanation  \
# 0             5.0  STEP 1: The purpose of the prompt is to unders...
# 1             5.0  The AI response demonstrates a completely cohe...
# 2             5.0  STEP 1: The purpose of the prompt is to unders...
# 3             5.0  STEP 1: The purpose is to explain how a reclin...
# 4             5.0  STEP 1: The purpose of the prompt is to unders...
# 5             5.0  STEP 1: The purpose is to inform the user abou...
# 6             5.0  STEP 1: The purpose of the response is to info...
# 7             5.0  STEP 1: The purpose of the response is to defi...
# 8             5.0  STEP 1: The purpose of the response is to expl...
# 9             5.0  The AI response demonstrates a completely cohe...
# 10            5.0  STEP 1: The purpose of the response is to info...
# 11            5.0  STEP 1: The purpose is to define and explain w...
# 12            5.0  The AI response demonstrates a completely cohe...
# 13            5.0  STEP 1: The purpose of the response is to info...
# 14            5.0  STEP 1: The purpose of the response is to defi...
# 15            5.0  STEP 1: The purpose is to explain the purpose ...
# 16            5.0  STEP 1: The purpose is to explain how foam den...
# 17            5.0  STEP 1: The purpose is to define "wall-mounted...
# 18            5.0  STEP 1: The purpose of the response is to expl...
# 19            5.0  STEP 1: The purpose of the text is to explain ...
# 20            5.0  STEP 1: The prompt seeks information on the me...
# 21            5.0  STEP 1: The purpose of the text is to inform t...
# 22            5.0  STEP 1: The purpose of the response is to expl...
# 23            5.0  STEP 1: The purpose of the response is to info...
# 24            5.0  STEP 1: The purpose of the response is to expl...
# 25            5.0  STEP 1: The purpose of the response is to expl...
# 26            5.0  STEP 1: The purpose is to explain what anti-sk...
# 27            5.0  STEP 1: The purpose is to inform the reader ab...
# 28            5.0  STEP 1: Identify the purpose and audience:\nTh...
# 29            5.0  STEP 1: The purpose is to explain the function...
# 30            5.0  STEP 1: The purpose is to explain the importan...
# 31            5.0  STEP 1: The purpose is to explain the meaning ...
# 32            5.0  STEP 1: The purpose of the response is to expl...
# 33            5.0  STEP 1: The purpose is to explain the differen...
# 34            5.0  STEP 1: The purpose of the response is to info...
# 35            5.0  STEP 1: The purpose is to explain the operatio...
# 36            5.0  STEP 1: The purpose is to define and explain t...
# 37            5.0  STEP 1: The purpose is to inform the user abou...
# 38            5.0  STEP 1: The purpose is to explain how stackabl...
# 39            5.0  STEP 1: The purpose is to explain the function...
# 40            5.0  The AI response demonstrates a clear and coher...
# 41            5.0  STEP 1: The purpose is to explain the swivel m...
# 42            5.0  STEP 1: The purpose of the text is to inform r...
# 43            5.0  STEP 1: The purpose of the response is to info...
# 44            5.0  STEP 1: The purpose is to explain the differen...
# 45            5.0  STEP 1: The purpose is to explain the role of ...
# 46            5.0  STEP 1: The purpose is to explain how a Murphy...
# 47            5.0  STEP 1: The purpose is to explain the signific...
# 48            5.0  STEP 1: The purpose is to explain what anti-ti...
# 49            5.0  STEP 1: The purpose is to inform the user abou...
#
#     coherence/score
# 0               5.0
# 1               5.0
# 2               5.0
# 3               5.0
# 4               5.0
# 5               5.0
# 6               5.0
# 7               5.0
# 8               5.0
# 9               5.0
# 10              5.0
# 11              5.0
# 12              5.0
# 13              5.0
# 14              5.0
# 15              5.0
# 16              5.0
# 17              5.0
# 18              5.0
# 19              5.0
# 20              5.0
# 21              5.0
# 22              5.0
# 23              5.0
# 24              5.0
# 25              5.0
# 26              5.0
# 27              5.0
# 28              5.0
# 29              5.0
# 30              5.0
# 31              5.0
# 32              5.0
# 33              5.0
# 34              5.0
# 35              5.0
# 36              5.0
# 37              5.0
# 38              5.0
# 39              5.0
# 40              5.0
# 41              5.0
# 42              5.0
# 43              5.0
# 44              3.0
# 45              5.0
# 46              5.0
# 47              5.0
# 48              5.0
# 49              5.0

# %%
eval_result.metadata
# Out:
# {'experiment': 'demo3-pairwise-experiment-eval-fine-tuned-model',
#  'experiment_run': 'demo3-pairwise-experiment-eval-fine-tuned-model'}

# %%
eval_result.summary_metrics
# Out:
# {'row_count': 50,
#  'bleu/mean': 0.021755236418,
#  'bleu/std': 0.026951018089257355,
#  'rouge_l_sum/mean': 0.12202883160000003,
#  'rouge_l_sum/std': 0.08553704473144383,
#  'fluency/mean': 5.0,
#  'fluency/std': 0.0,
#  'coherence/mean': 4.96,
#  'coherence/std': 0.282842712474619}

# %%
eval_result.metrics_table.to_csv("eval_result.csv")
